# %%
import pandas as pd

df = pd.read_csv('pipe_type_counts.csv')
df
# Out:
#      fid  ... steam_count
# 0      1  ...         NaN
# 1      2  ...         NaN
# 2      3  ...         NaN
# 3      4  ...         NaN
# 4      5  ...         NaN
# ..   ...  ...         ...
# 105  118  ...         NaN
# 106  119  ...         NaN
# 107  120  ...         NaN
# 108  121  ...         NaN
# 109  122  ...         NaN
#
# [110 rows x 13 columns]

# %%
pipe_counts = df[['air_count','oil_count','standpipe_count','box_count','steam_count']].sum()
pipe_counts
# Out:
# air_count          44.0
# oil_count          27.0
# standpipe_count    58.0
# box_count           2.0
# steam_count         1.0
# dtype: float64

# %%
total_pipes = pipe_counts.sum()
total_pipes
# Out:
# np.float64(132.0)

# %%
pipe_counts.to_csv('pipe_type_counts_sum.csv')
